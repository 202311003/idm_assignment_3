# %%
# Create a new directory named "data"
# !mkdir /content/data

# %%
import os
import json
import pandas as pd

# Specify the path to the folder containing JSON files
folder_path = '/content/data/odis_json'  # Update this with the correct path to your folder

# Initialize empty lists to store extracted data
extracted_data = []

# Iterate through each file in the folder
for json_file_name in os.listdir(folder_path):
    # Check if the file is a JSON file
    if json_file_name.endswith('.json'):
        # Create the full file path
        file_path = os.path.join(folder_path, json_file_name)

        # Open and load the JSON file
        with open(file_path, 'r', encoding='utf-8') as json_file:
            try:
                # Load JSON data from the file
                json_data = json.load(json_file)

                # Extract specific data from the JSON
                data = {
                'City': json_data['info'].get('city'),
                'Dates': json_data['info']['dates'][0] if json_data['info'].get('dates') else None,
                'Event Name': json_data['info']['event']['name'],
                'Match Group': json_data['info']['event'].get('group', None),
                'Stage': json_data['info']['event'].get('stage','in qualification'),
                'Match Number': json_data['info']['event'].get('match_number'),
                'Gender': json_data['info']['gender'],
                'Match Type': json_data['info']['match_type'],
                'Winner': json_data['info']['outcome'].get('winner'),
                'Overs': json_data['info'].get('overs'),
                'Player of the Match': json_data['info'].get('player_of_match', None),
                'Team 1': json_data['info']['teams'][0],
                'Team 2': json_data['info']['teams'][1],
                'Team 1 Players': ', '.join(json_data['info']['players'][json_data['info']['teams'][0]]),
                'Team 2 Players': ', '.join(json_data['info']['players'][json_data['info']['teams'][1]])
                }

                # Append data to the list
                extracted_data.append(data)
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON file {json_file_name}: {e}")

# Create a DataFrame from the extracted data
df = pd.DataFrame(extracted_data)

# Display the resulting DataFrame
print(df)

# Optionally, save the DataFrame to a CSV file
csv_file_path = '/content/extracted_data.csv'
df.to_csv(csv_file_path, index=False)

# Download the CSV file
from google.colab import files
files.download(csv_file_path)
# Out:
#           City       Dates             Event Name Match Group  \
# 0      Kolkata  2023-10-28  ICC Cricket World Cup        None
# 1         Pune  2023-11-08  ICC Cricket World Cup        None
# 2      Lucknow  2023-10-16  ICC Cricket World Cup        None
# 3        Delhi  2023-10-11  ICC Cricket World Cup        None
# 4    Ahmedabad  2023-11-10  ICC Cricket World Cup        None
# 5       Mumbai  2023-10-24  ICC Cricket World Cup        None
# 6      Chennai  2023-10-27  ICC Cricket World Cup        None
# 7        Delhi  2023-11-06  ICC Cricket World Cup        None
# 8      Lucknow  2023-10-29  ICC Cricket World Cup        None
# 9        Delhi  2023-10-07  ICC Cricket World Cup        None
# 10     Chennai  2023-10-23  ICC Cricket World Cup        None
# 11   Ahmedabad  2023-10-05  ICC Cricket World Cup        None
# 12     Lucknow  2023-10-21  ICC Cricket World Cup        None
# 13  Dharamsala  2023-10-17  ICC Cricket World Cup        None
# 14   Ahmedabad  2023-11-04  ICC Cricket World Cup        None
# 15   Bengaluru  2023-11-04  ICC Cricket World Cup        None
# 16     Lucknow  2023-10-12  ICC Cricket World Cup        None
# 17     Chennai  2023-10-18  ICC Cricket World Cup        None
# 18        Pune  2023-11-01  ICC Cricket World Cup        None
# 19  Dharamsala  2023-10-22  ICC Cricket World Cup        None
# 20   Bengaluru  2023-11-09  ICC Cricket World Cup        None
# 21     Lucknow  2023-11-03  ICC Cricket World Cup        None
# 22   Hyderabad  2023-10-06  ICC Cricket World Cup        None
# 23  Dharamsala  2023-10-28  ICC Cricket World Cup        None
# 24      Mumbai  2023-10-21  ICC Cricket World Cup        None
# 25   Ahmedabad  2023-10-14  ICC Cricket World Cup        None
# 26  Dharamsala  2023-10-10  ICC Cricket World Cup        None
# 27      Mumbai  2023-11-07  ICC Cricket World Cup        None
# 28     Kolkata  2023-10-31  ICC Cricket World Cup        None
# 29   Hyderabad  2023-10-09  ICC Cricket World Cup        None
# 30   Hyderabad  2023-10-10  ICC Cricket World Cup        None
# 31  Dharamsala  2023-10-07  ICC Cricket World Cup        None
# 32        Pune  2023-10-19  ICC Cricket World Cup        None
# 33   Bengaluru  2023-10-20  ICC Cricket World Cup        None
# 34      Mumbai  2023-11-02  ICC Cricket World Cup        None
# 35        Pune  2023-10-30  ICC Cricket World Cup        None
# 36   Bengaluru  2023-10-26  ICC Cricket World Cup        None
# 37     Kolkata  2023-11-05  ICC Cricket World Cup        None
# 38       Delhi  2023-10-15  ICC Cricket World Cup        None
# 39     Chennai  2023-10-13  ICC Cricket World Cup        None
# 40     Chennai  2023-10-08  ICC Cricket World Cup        None
# 41       Delhi  2023-10-25  ICC Cricket World Cup        None
#
#                Stage  Match Number Gender Match Type        Winner  Overs  \
# 0   in qualification            28   male        ODI   Netherlands     50
# 1   in qualification            40   male        ODI       England     50
# 2   in qualification            14   male        ODI     Australia     50
# 3   in qualification             9   male        ODI         India     50
# 4   in qualification            42   male        ODI  South Africa     50
# 5   in qualification            23   male        ODI  South Africa     50
# 6   in qualification            26   male        ODI  South Africa     50
# 7   in qualification            38   male        ODI    Bangladesh     50
# 8   in qualification            29   male        ODI         India     50
# 9   in qualification             4   male        ODI  South Africa     50
# 10  in qualification            22   male        ODI   Afghanistan     50
# 11  in qualification             1   male        ODI   New Zealand     50
# 12  in qualification            19   male        ODI     Sri Lanka     50
# 13  in qualification            15   male        ODI   Netherlands     50
# 14  in qualification            36   male        ODI     Australia     50
# 15  in qualification            35   male        ODI      Pakistan     50
# 16  in qualification            10   male        ODI  South Africa     50
# 17  in qualification            16   male        ODI   New Zealand     50
# 18  in qualification            32   male        ODI  South Africa     50
# 19  in qualification            21   male        ODI         India     50
# 20  in qualification            41   male        ODI   New Zealand     50
# 21  in qualification            34   male        ODI   Afghanistan     50
# 22  in qualification             2   male        ODI      Pakistan     50
# 23  in qualification            27   male        ODI     Australia     50
# 24  in qualification            20   male        ODI  South Africa     50
# 25  in qualification            12   male        ODI         India     50
# 26  in qualification             7   male        ODI       England     50
# 27  in qualification            39   male        ODI     Australia     50
# 28  in qualification            31   male        ODI      Pakistan     50
# 29  in qualification             6   male        ODI   New Zealand     50
# 30  in qualification             8   male        ODI      Pakistan     50
# 31  in qualification             3   male        ODI    Bangladesh     50
# 32  in qualification            17   male        ODI         India     50
# 33  in qualification            18   male        ODI     Australia     50
# 34  in qualification            33   male        ODI         India     50
# 35  in qualification            30   male        ODI   Afghanistan     50
# 36  in qualification            25   male        ODI     Sri Lanka     50
# 37  in qualification            37   male        ODI         India     50
# 38  in qualification            13   male        ODI   Afghanistan     50
# 39  in qualification            11   male        ODI   New Zealand     50
# 40  in qualification             5   male        ODI         India     50
# 41  in qualification            24   male        ODI     Australia     50
#
#      Player of the Match        Team 1        Team 2  \
# 0      [PA van Meekeren]   Netherlands    Bangladesh
# 1            [BA Stokes]       England   Netherlands
# 2              [A Zampa]     Sri Lanka     Australia
# 3            [RG Sharma]   Afghanistan         India
# 4    [HE van der Dussen]   Afghanistan  South Africa
# 5            [Q de Kock]  South Africa    Bangladesh
# 6             [T Shamsi]      Pakistan  South Africa
# 7      [Shakib Al Hasan]     Sri Lanka    Bangladesh
# 8            [RG Sharma]         India       England
# 9           [AK Markram]  South Africa     Sri Lanka
# 10      [Ibrahim Zadran]      Pakistan   Afghanistan
# 11          [R Ravindra]       England   New Zealand
# 12    [S Samarawickrama]   Netherlands     Sri Lanka
# 13          [SA Edwards]   Netherlands  South Africa
# 14             [A Zampa]     Australia       England
# 15        [Fakhar Zaman]   New Zealand      Pakistan
# 16           [Q de Kock]  South Africa     Australia
# 17         [GD Phillips]   New Zealand   Afghanistan
# 18   [HE van der Dussen]  South Africa   New Zealand
# 19      [Mohammed Shami]   New Zealand         India
# 20            [TA Boult]     Sri Lanka   New Zealand
# 21       [Mohammad Nabi]   Netherlands   Afghanistan
# 22        [Saud Shakeel]      Pakistan   Netherlands
# 23             [TM Head]     Australia   New Zealand
# 24           [H Klaasen]  South Africa       England
# 25           [JJ Bumrah]      Pakistan         India
# 26            [DJ Malan]       England    Bangladesh
# 27          [GJ Maxwell]   Afghanistan     Australia
# 28        [Fakhar Zaman]    Bangladesh      Pakistan
# 29          [MJ Santner]   New Zealand   Netherlands
# 30     [Mohammad Rizwan]     Sri Lanka      Pakistan
# 31  [Mehedi Hasan Miraz]   Afghanistan    Bangladesh
# 32             [V Kohli]    Bangladesh         India
# 33           [DA Warner]     Australia      Pakistan
# 34      [Mohammed Shami]         India     Sri Lanka
# 35    [Fazalhaq Farooqi]     Sri Lanka   Afghanistan
# 36        [CBRLS Kumara]       England     Sri Lanka
# 37             [V Kohli]         India  South Africa
# 38    [Mujeeb Ur Rahman]   Afghanistan       England
# 39         [LH Ferguson]    Bangladesh   New Zealand
# 40            [KL Rahul]     Australia         India
# 41          [GJ Maxwell]     Australia   Netherlands
#
#                                        Team 1 Players  \
# 0   Vikramjit Singh, MP O'Dowd, W Barresi, CN Acke...
# 1   JM Bairstow, DJ Malan, JE Root, BA Stokes, HC ...
# 2   P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 3   Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 4   Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 5   Q de Kock, RR Hendricks, HE van der Dussen, AK...
# 6   Usama Mir, Abdullah Shafique, Imam-ul-Haq, Bab...
# 7   P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 8   RG Sharma, Shubman Gill, V Kohli, SS Iyer, KL ...
# 9   Q de Kock, T Bavuma, HE van der Dussen, AK Mar...
# 10  Abdullah Shafique, Imam-ul-Haq, Babar Azam, Mo...
# 11  JM Bairstow, DJ Malan, JE Root, HC Brook, MM A...
# 12  Vikramjit Singh, MP O'Dowd, CN Ackermann, BFW ...
# 13  Vikramjit Singh, MP O'Dowd, CN Ackermann, BFW ...
# 14  TM Head, DA Warner, SPD Smith, M Labuschagne, ...
# 15  DP Conway, R Ravindra, KS Williamson, DJ Mitch...
# 16  Q de Kock, T Bavuma, HE van der Dussen, AK Mar...
# 17  DP Conway, WA Young, R Ravindra, DJ Mitchell, ...
# 18  Q de Kock, T Bavuma, HE van der Dussen, DA Mil...
# 19  DP Conway, WA Young, R Ravindra, DJ Mitchell, ...
# 20  P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 21  W Barresi, MP O'Dowd, CN Ackermann, SA Engelbr...
# 22  Fakhar Zaman, Imam-ul-Haq, Babar Azam, Mohamma...
# 23  DA Warner, TM Head, MR Marsh, SPD Smith, M Lab...
# 24  Q de Kock, RR Hendricks, HE van der Dussen, AK...
# 25  Abdullah Shafique, Imam-ul-Haq, Babar Azam, Mo...
# 26  JM Bairstow, DJ Malan, JE Root, JC Buttler, HC...
# 27  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 28  Tanzid Hasan, Liton Das, Nazmul Hossain Shanto...
# 29  DP Conway, WA Young, R Ravindra, DJ Mitchell, ...
# 30  P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 31  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 32  Tanzid Hasan, Liton Das, Nazmul Hossain Shanto...
# 33  DA Warner, MR Marsh, GJ Maxwell, SPD Smith, MP...
# 34  RG Sharma, Shubman Gill, V Kohli, SS Iyer, KL ...
# 35  P Nissanka, FDM Karunaratne, BKG Mendis, S Sam...
# 36  JM Bairstow, DJ Malan, JE Root, BA Stokes, JC ...
# 37  RG Sharma, Shubman Gill, V Kohli, SS Iyer, KL ...
# 38  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 39  Liton Das, Tanzid Hasan, Mehedi Hasan Miraz, N...
# 40  DA Warner, MR Marsh, SPD Smith, M Labuschagne,...
# 41  MR Marsh, DA Warner, SPD Smith, M Labuschagne,...
#
#                                        Team 2 Players
# 0   Liton Das, Tanzid Hasan, Mehedi Hasan Miraz, N...
# 1   W Barresi, MP O'Dowd, CN Ackermann, SA Engelbr...
# 2   MR Marsh, DA Warner, SPD Smith, M Labuschagne,...
# 3   RG Sharma, Ishan Kishan, V Kohli, SS Iyer, KL ...
# 4   Q de Kock, T Bavuma, HE van der Dussen, AK Mar...
# 5   Tanzid Hasan, Liton Das, Nazmul Hossain Shanto...
# 6   T Bavuma, Q de Kock, HE van der Dussen, AK Mar...
# 7   Tanzid Hasan, Liton Das, Nazmul Hossain Shanto...
# 8   JM Bairstow, DJ Malan, JE Root, BA Stokes, JC ...
# 9   P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 10  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 11  DP Conway, WA Young, R Ravindra, DJ Mitchell, ...
# 12  P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 13  T Bavuma, Q de Kock, HE van der Dussen, AK Mar...
# 14  JM Bairstow, DJ Malan, JE Root, BA Stokes, JC ...
# 15  Abdullah Shafique, Fakhar Zaman, Babar Azam, M...
# 16  MR Marsh, DA Warner, SPD Smith, M Labuschagne,...
# 17  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 18  DP Conway, WA Young, R Ravindra, DJ Mitchell, ...
# 19  RG Sharma, Shubman Gill, V Kohli, SS Iyer, KL ...
# 20  DP Conway, R Ravindra, KS Williamson, DJ Mitch...
# 21  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 22  Vikramjit Singh, MP O'Dowd, CN Ackermann, BFW ...
# 23  DP Conway, WA Young, R Ravindra, DJ Mitchell, ...
# 24  JM Bairstow, DJ Malan, JE Root, BA Stokes, HC ...
# 25  RG Sharma, Shubman Gill, V Kohli, SS Iyer, KL ...
# 26  Liton Das, Tanzid Hasan, Nazmul Hossain Shanto...
# 27  DA Warner, TM Head, MR Marsh, M Labuschagne, J...
# 28  Abdullah Shafique, Fakhar Zaman, Babar Azam, M...
# 29  Vikramjit Singh, MP O'Dowd, CN Ackermann, BFW ...
# 30  Abdullah Shafique, Imam-ul-Haq, Babar Azam, Mo...
# 31  Tanzid Hasan, Liton Das, Mehedi Hasan Miraz, N...
# 32  RG Sharma, Shubman Gill, V Kohli, SS Iyer, KL ...
# 33  Abdullah Shafique, Imam-ul-Haq, Babar Azam, Mo...
# 34  P Nissanka, FDM Karunaratne, BKG Mendis, S Sam...
# 35  Rahmanullah Gurbaz, Ibrahim Zadran, Rahmat Sha...
# 36  P Nissanka, MDKJ Perera, BKG Mendis, S Samaraw...
# 37  Q de Kock, T Bavuma, HE van der Dussen, AK Mar...
# 38  JM Bairstow, DJ Malan, JE Root, HC Brook, JC B...
# 39  DP Conway, R Ravindra, KS Williamson, DJ Mitch...
# 40  RG Sharma, Ishan Kishan, V Kohli, SS Iyer, KL ...
# 41  Vikramjit Singh, MP O'Dowd, CN Ackermann, SA E...

# %%
import csv
from google.colab import files

# Data in the form of a dictionary
teams_data = {
    'Bangladesh': ['Shakib Al Hasan (C)', 'Litton Das (VC)', 'Najmul Hossain Shanto', 'Tanzid Hasan', 'Towhid Hridoy', 'Mahmudullah Riyad', 'Mushfiqur Rahim', 'Mehidy Hasan', 'Mahedi Hasan', 'Tanzim Sakib', 'Nasum Ahmed', 'Shoriful Islam', 'Hasan Mahmud', 'Taskin Ahmed', 'Mustafizur'],
    'England': ['Jos Buttler (c)', 'Moeen Ali', 'Gus Atkinson', 'Jonny Bairstow', 'Sam Curran', 'Liam Livingstone', 'Dawid Malan', 'Adil Rashid', 'Joe Root', 'Jason Roy', 'Ben Stokes', 'Reece Topley','Brydon Carse', 'David Willey', 'Mark Wood', 'Chris Woakes'],
    'India': ['Rohit Sharma (c)', 'Shubman Gill', 'Virat Kohli', 'Shreyas Iyer', 'KL Rahul', 'Ishan Kishan', 'Suryakumar Yadav', 'Hardik Pandya','Prasidh Krishna', 'Ravindra Jadeja', 'Axar Patel', 'Shardul Thakur', 'Jasprit Bumrah', 'Kuldeep Yadav', 'Mohammed Shami', 'Mohammed Siraj'],
    'Netherlands': ['Scott Edwards (c)', 'Max O\'Dowd', 'Bas de Leede', 'Vikram Singh', 'Teja Nidamanuru', 'Paul van Meekeren', 'Colin Ackermann', 'Roelof van der Merwe', 'Logan van Beek', 'Aryan Dutt', 'Ryan Klein', 'Wesley Barresi', 'Saqib Zulfiqar', 'Shariz Ahmad', 'Sybrand Engelbrecht'],
    'New Zealand': ['Kane Williamson (c)', 'Trent Boult', 'Mark Chapman', 'Devon Conway', 'Lockie Ferguson', 'Matt Henry (injured, replaced by Kyle Jamieson)', 'Tom Latham (vc, wk)', 'Daryl Mitchell', 'Jimmy Neesham', 'Glenn Phillips', 'Rachin Ravindra', 'Mitchell Santner', 'Ish Sodhi', 'Tim Southee', 'Will Young'],
    'Pakistan': ['Babar Azam (c)', 'Shadab Khan', 'Abdullah Shafique', 'Fakhar Zaman', 'Haris Rauf', 'Hasan Ali', 'Iftikhar Ahmed', 'Imam-ul-Haq', 'Mohammad Nawaz', 'Mohammad Rizwan (wk)', 'Mohammad Wasim Jnr', 'Salman Ali Agha', 'Saud Shakeel', 'Shaheen Shah Afridi and Usama Mir'],
    'South Africa': ['Temba Bavuma (c)', 'Gerald Coetzee', 'Quinton de Kock', 'Reeza Hendricks', 'Marco Jansen', 'Heinrich Klaasen', 'Keshav Maharaj', 'Aiden Markram', 'David Miller', 'Lungi Ngidi', 'Andile Phehlukwayo', 'Kagiso Rabada', 'Tabraiz Shamsi', 'Rassie van der Dussen', 'Lizaad Williams'],
    'Sri Lanka': ['Dasun Shanaka (c) (injured, replaced by Chamika Karunaratne)', 'Kusal Mendis (vc)', 'Kusal Perera', 'Pathum Nissanka', 'Dimuth Karunaratne', 'Sadeera Samarawickrama', 'Charith Asalanka', 'Dhananjaya de Silva', 'Dushan Hemantha', 'Maheesh Theekshana', 'Dunith Wellalage', 'Kasun Rajitha', 'Matheesha Pathirana (injured, replaced by Angelo Mathews)', 'Lahiru Kumara (injured, replaced by Dushmantha Chameera)', 'Dilshan Madushanka'],
    'Afghanistan': ['Hashmatullah Shahidi (c)', 'Rahmanullah Gurbaz', 'Ibrahim Zadran', 'Riaz Hassan', 'Rahmat Shah', 'Najibullah Zadran', 'Mohammad Nabi', 'Ikram Alikhil', 'Azmatullah Omarzai', 'Rashid Khan', 'Mujeeb ur Rahman', 'Noor Ahmad', 'Fazalhaq Farooqi', 'Abdul Rahman', 'Naveen ul Haq'],
    'Australia': ['Pat Cummins', 'Sean Abbott', 'Alex Carey', 'Cameron Green', 'Josh Hazlewood', 'Travis Head', 'Josh Inglis', 'Marnus Labuschagne', 'Mitchell Marsh', 'Glenn Maxwell', 'Steven Smith', 'Mitchell Starc', 'Marcus Stoinis', 'David Warner', 'Adam Zampa']
}

# Create a CSV file and write data to it
with open('cricket_players.csv', 'w', newline='') as csvfile:
    fieldnames = ['Country', 'Player', 'Position', 'Injured', 'Replaced With']
    writer = csv.writer(csvfile)
    writer.writerow(fieldnames)

    for country, players in teams_data.items():
        for player in players:
            position = ''
            if '(c)' in player:
                position += 'Captain, '
            elif '(vc)' in player:
                position += 'Vice Captain, '
            elif '(wk)' in player:
                position += 'Wicket Keeper, '
            else:
                position += 'N/A, '

            injured = 'Injured' if 'injured' in player else 'N/A'
            replaced_with = player.split('replaced by ')[1].strip() if 'replaced by' in player else 'N/A'
            player_name = player.split('(')[0].strip()

            # Write data to CSV file
            writer.writerow([country, player_name, position[:-2], injured, replaced_with])

# Download the CSV file
files.download('cricket_players.csv')

# %%
files.download('output.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-9efa3dbf9c70> in <cell line: 1>()
# ----> 1 files.download('output.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: output.csv

# %%
import json
import os
import csv

# List of all player names
player_names = ['TA Boult', 'MJ Henry', 'MJ Santner', 'JDS Neesham', 'R Ravindra',
       'GD Phillips', 'CR Woakes', 'SM Curran', 'MA Wood', 'MM Ali',
       'AU Rashid', 'LS Livingstone', 'A Dutt', 'LV van Beek',
       'CN Ackermann', 'PA van Meekeren', 'BFW de Leede',
       'RE van der Merwe', 'Vikramjit Singh', 'Saqib Zulfiqar',
       'Shaheen Shah Afridi', 'Hasan Ali', 'Haris Rauf', 'Iftikhar Ahmed',
       'Mohammad Nawaz', 'Shadab Khan', 'Taskin Ahmed', 'Shoriful Islam',
       'Mustafizur Rahman', 'Shakib Al Hasan', 'Mehedi Hasan Miraz',
       'Mahmudullah', 'Fazalhaq Farooqi', 'Mujeeb Ur Rahman',
       'Naveen-ul-Haq', 'Rashid Khan', 'Mohammad Nabi',
       'Azmatullah Omarzai', 'CAK Rajitha', 'D Madushanka', 'MD Shanaka',
       'DM de Silva', 'M Pathirana', 'DN Wellalage', 'L Ngidi',
       'M Jansen', 'K Rabada', 'KA Maharaj', 'G Coetzee', 'JJ Bumrah',
       'Mohammed Siraj', 'HH Pandya', 'R Ashwin', 'Kuldeep Yadav',
       'RA Jadeja', 'MA Starc', 'JR Hazlewood', 'PJ Cummins',
       'GJ Maxwell', 'C Green', 'A Zampa', 'R Klein', 'LH Ferguson',
       'Mahedi Hasan', 'RJW Topley', 'M Theekshana', 'KIC Asalanka',
       'SN Thakur', 'MR Marsh', 'MP Stoinis', 'T Shamsi', 'DJ Mitchell',
       'JE Root', 'CBRLS Kumara', 'C Karunaratne', 'Nasum Ahmed',
       'Hasan Mahmud', 'Usama Mir', 'MADI Hemantha', 'DJ Willey',
       'AAP Atkinson', 'Mohammed Shami', 'Noor Ahmad', 'LB Williams',
       'AD Mathews', 'AK Markram', 'Mohammad Wasim', 'Shariz Ahmad',
       'PVD Chameera', 'Nazmul Hossain Shanto', 'TG Southee',
       'Agha Salman', 'IS Sodhi', 'TM Head', 'Tanzim Hasan Sakib',
       'AL Phehlukwayo', 'Rahmat Shah', 'JM Bairstow', 'DJ Malan',
       'HC Brook', 'JC Buttler', 'DP Conway', 'WA Young', 'Fakhar Zaman',
       'Imam-ul-Haq', 'Babar Azam', 'Mohammad Rizwan', 'Saud Shakeel',
       "MP O'Dowd", 'AT Nidamanuru', 'SA Edwards', 'Rahmanullah Gurbaz',
       'Ibrahim Zadran', 'Hashmatullah Shahidi', 'Najibullah Zadran',
       'Tanzid Hasan', 'Liton Das', 'Mushfiqur Rahim', 'Q de Kock',
       'T Bavuma', 'HE van der Dussen', 'H Klaasen', 'DA Miller',
       'P Nissanka', 'MDKJ Perera', 'BKG Mendis', 'S Samarawickrama',
       'DA Warner', 'SPD Smith', 'M Labuschagne', 'AT Carey', 'RG Sharma',
       'Ishan Kishan', 'V Kohli', 'SS Iyer', 'KL Rahul', 'TWM Latham',
       'MS Chapman', 'SA Engelbrecht', 'Towhid Hridoy',
       'Abdullah Shafique', 'JP Inglis', 'KS Williamson', 'Shubman Gill',
       'Ikram Alikhil', 'RR Hendricks', 'BA Stokes', 'SA Yadav',
       'W Barresi', 'FDM Karunaratne']

# Dictionary to store player statistics
player_stats = {player: {'Runs': 0, 'Fours': 0, 'Sixes': 0, 'Wickets': 0, 'Balls Bowled': 0} for player in player_names}

# Directory containing the JSON files
json_folder_path = '/content/data/odis_json'  # Replace with the actual folder path containing JSON files

# Iterate through JSON files in the folder
for filename in os.listdir(json_folder_path):
    if filename.endswith('.json'):  # Check if the file has a .json extension
        with open(os.path.join(json_folder_path, filename), 'r') as jsonfile:
            data = json.load(jsonfile)

            # Check if the gender is male
            if data['info']['gender'] == 'male':
                for inning in data['innings']:
                    for over in inning['overs']:
                        for ball in over['deliveries']:
                            batter = ball['batter']
                            runs = ball['runs']['batter']
                            extras = ball['runs']['extras']
                            bowler = ball['bowler']
                            wicket = 1 if 'wickets' in over and batter in [w['player_out'] for w in over['wickets']] else 0

                            # Update player statistics only for the specified players
                            if batter in player_names:
                                player_stats[batter]['Runs'] += runs
                                player_stats[batter]['Fours'] += 1 if runs == 4 else 0
                                player_stats[batter]['Sixes'] += 1 if runs == 6 else 0
                                player_stats[batter]['Wickets'] += wicket
                            if wicket == 1 and bowler in player_names:
                                player_stats[bowler]['Wickets'] += 1
                            if bowler in player_names:
                                player_stats[bowler]['Balls Bowled'] += 1

# Write player statistics to a CSV file
csv_file_path = '/content/player_stats.csv'  # Replace with the desired CSV file path
with open(csv_file_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)

    # Write header row
    csvwriter.writerow(['Player Name', 'Runs', 'Fours', 'Sixes', 'Wickets', 'Balls Bowled'])

    # Write player statistics rows
    for player, stats in player_stats.items():
        csvwriter.writerow([player, stats['Runs'], stats['Fours'], stats['Sixes'], stats['Wickets'], stats['Balls Bowled']])

print(f"Player statistics have been saved to {csv_file_path}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-42a19d2dd4c9> in <cell line: 52>()
#      71                                 player_stats[batter]['Fours'] += 1 if runs == 4 else 0
#      72                                 player_stats[batter]['Sixes'] += 1 if runs == 6 else 0
# ---> 73                                 player_stats[batter]['wickets'] += wicket
#      74                             if wicket == 1 and bowler in player_names:
#      75                                 player_stats[bowler]['Wickets'] += 1
#
# KeyError: 'wickets'

# %%
from google.colab import files

# Specify the path to your CSV file
csv_file_path = '/content/player_stats.csv'  # Update this path if necessary

# Trigger the download of the CSV file
files.download(csv_file_path)

# %%
import json
import os

# List of all player names
player_names = ['TA Boult', 'MJ Henry', 'MJ Santner', 'JDS Neesham', 'R Ravindra',
       'GD Phillips', 'CR Woakes', 'SM Curran', 'MA Wood', 'MM Ali',
       'AU Rashid', 'LS Livingstone', 'A Dutt', 'LV van Beek',
       'CN Ackermann', 'PA van Meekeren', 'BFW de Leede',
       'RE van der Merwe', 'Vikramjit Singh', 'Saqib Zulfiqar',
       'Shaheen Shah Afridi', 'Hasan Ali', 'Haris Rauf', 'Iftikhar Ahmed',
       'Mohammad Nawaz', 'Shadab Khan', 'Taskin Ahmed', 'Shoriful Islam',
       'Mustafizur Rahman', 'Shakib Al Hasan', 'Mehedi Hasan Miraz',
       'Mahmudullah', 'Fazalhaq Farooqi', 'Mujeeb Ur Rahman',
       'Naveen-ul-Haq', 'Rashid Khan', 'Mohammad Nabi',
       'Azmatullah Omarzai', 'CAK Rajitha', 'D Madushanka', 'MD Shanaka',
       'DM de Silva', 'M Pathirana', 'DN Wellalage', 'L Ngidi',
       'M Jansen', 'K Rabada', 'KA Maharaj', 'G Coetzee', 'JJ Bumrah',
       'Mohammed Siraj', 'HH Pandya', 'R Ashwin', 'Kuldeep Yadav',
       'RA Jadeja', 'MA Starc', 'JR Hazlewood', 'PJ Cummins',
       'GJ Maxwell', 'C Green', 'A Zampa', 'R Klein', 'LH Ferguson',
       'Mahedi Hasan', 'RJW Topley', 'M Theekshana', 'KIC Asalanka',
       'SN Thakur', 'MR Marsh', 'MP Stoinis', 'T Shamsi', 'DJ Mitchell',
       'JE Root', 'CBRLS Kumara', 'C Karunaratne', 'Nasum Ahmed',
       'Hasan Mahmud', 'Usama Mir', 'MADI Hemantha', 'DJ Willey',
       'AAP Atkinson', 'Mohammed Shami', 'Noor Ahmad', 'LB Williams',
       'AD Mathews', 'AK Markram', 'Mohammad Wasim', 'Shariz Ahmad',
       'PVD Chameera', 'Nazmul Hossain Shanto', 'TG Southee',
       'Agha Salman', 'IS Sodhi', 'TM Head', 'Tanzim Hasan Sakib',
       'AL Phehlukwayo', 'Rahmat Shah', 'JM Bairstow', 'DJ Malan',
       'HC Brook', 'JC Buttler', 'DP Conway', 'WA Young', 'Fakhar Zaman',
       'Imam-ul-Haq', 'Babar Azam', 'Mohammad Rizwan', 'Saud Shakeel',
       "MP O'Dowd", 'AT Nidamanuru', 'SA Edwards', 'Rahmanullah Gurbaz',
       'Ibrahim Zadran', 'Hashmatullah Shahidi', 'Najibullah Zadran',
       'Tanzid Hasan', 'Liton Das', 'Mushfiqur Rahim', 'Q de Kock',
       'T Bavuma', 'HE van der Dussen', 'H Klaasen', 'DA Miller',
       'P Nissanka', 'MDKJ Perera', 'BKG Mendis', 'S Samarawickrama',
       'DA Warner', 'SPD Smith', 'M Labuschagne', 'AT Carey', 'RG Sharma',
       'Ishan Kishan', 'V Kohli', 'SS Iyer', 'KL Rahul', 'TWM Latham',
       'MS Chapman', 'SA Engelbrecht', 'Towhid Hridoy',
       'Abdullah Shafique', 'JP Inglis', 'KS Williamson', 'Shubman Gill',
       'Ikram Alikhil', 'RR Hendricks', 'BA Stokes', 'SA Yadav',
       'W Barresi', 'FDM Karunaratne']


# Dictionary to store bowler wickets
bowler_wickets = {player: 0 for player in player_names}

# Directory containing the JSON files
json_folder_path = '/content/data/odis_json'  # Replace with the actual folder path containing JSON files

# Iterate through JSON files in the folder
for filename in os.listdir(json_folder_path):
    if filename.endswith('.json'):  # Check if the file has a .json extension
        with open(os.path.join(json_folder_path, filename), 'r') as jsonfile:
            data = json.load(jsonfile)

            # Check if the gender is male
            if data['info']['gender'] == 'male':
                for inning in data['innings']:
                    for over in inning['overs']:
                        for delivery in over['deliveries']:
                            # Check if there is a wicket in the delivery
                            if 'wickets' in delivery:
                                for wicket in delivery['wickets']:
                                    player_out = wicket.get('player_out', None)
                                    kind = wicket.get('kind', None)
                                    bowler = delivery['bowler']
                                    if player_out and player_out in player_names and kind != 'run out' and bowler in player_names:
                                        bowler_wickets[bowler] += 1

# Print the total number of wickets taken by each bowler
for bowler, wickets in bowler_wickets.items():
    print(f"{bowler}: {wickets} wickets")

    # Write the data to a CSV file
csv_file_path = '/content/bowler_wickets.csv'  # Replace with the desired CSV file path
with open(csv_file_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)

    # Write header row
    csvwriter.writerow(['Bowler', 'Wickets'])

    # Write bowler wickets data
    for bowler, wickets in bowler_wickets.items():
        csvwriter.writerow([bowler, wickets])

print(f"Bowler-wise wickets data has been saved to {csv_file_path}")
# Out:
# TA Boult: 13 wickets
# MJ Henry: 11 wickets
# MJ Santner: 16 wickets
# JDS Neesham: 2 wickets
# R Ravindra: 5 wickets
# GD Phillips: 6 wickets
# CR Woakes: 9 wickets
# SM Curran: 2 wickets
# MA Wood: 6 wickets
# MM Ali: 3 wickets
# AU Rashid: 13 wickets
# LS Livingstone: 3 wickets
# A Dutt: 10 wickets
# LV van Beek: 12 wickets
# CN Ackermann: 5 wickets
# PA van Meekeren: 11 wickets
# BFW de Leede: 14 wickets
# RE van der Merwe: 5 wickets
# Vikramjit Singh: 0 wickets
# Saqib Zulfiqar: 1 wickets
# Shaheen Shah Afridi: 16 wickets
# Hasan Ali: 9 wickets
# Haris Rauf: 13 wickets
# Iftikhar Ahmed: 3 wickets
# Mohammad Nawaz: 2 wickets
# Shadab Khan: 2 wickets
# Taskin Ahmed: 4 wickets
# Shoriful Islam: 10 wickets
# Mustafizur Rahman: 5 wickets
# Shakib Al Hasan: 10 wickets
# Mehedi Hasan Miraz: 10 wickets
# Mahmudullah: 0 wickets
# Fazalhaq Farooqi: 6 wickets
# Mujeeb Ur Rahman: 8 wickets
# Naveen-ul-Haq: 8 wickets
# Rashid Khan: 11 wickets
# Mohammad Nabi: 8 wickets
# Azmatullah Omarzai: 7 wickets
# CAK Rajitha: 8 wickets
# D Madushanka: 21 wickets
# MD Shanaka: 0 wickets
# DM de Silva: 0 wickets
# M Pathirana: 2 wickets
# DN Wellalage: 2 wickets
# L Ngidi: 10 wickets
# M Jansen: 17 wickets
# K Rabada: 12 wickets
# KA Maharaj: 14 wickets
# G Coetzee: 18 wickets
# JJ Bumrah: 15 wickets
# Mohammed Siraj: 10 wickets
# HH Pandya: 5 wickets
# R Ashwin: 1 wickets
# Kuldeep Yadav: 12 wickets
# RA Jadeja: 14 wickets
# MA Starc: 10 wickets
# JR Hazlewood: 12 wickets
# PJ Cummins: 10 wickets
# GJ Maxwell: 5 wickets
# C Green: 0 wickets
# A Zampa: 20 wickets
# R Klein: 0 wickets
# LH Ferguson: 10 wickets
# Mahedi Hasan: 6 wickets
# RJW Topley: 8 wickets
# M Theekshana: 6 wickets
# KIC Asalanka: 0 wickets
# SN Thakur: 2 wickets
# MR Marsh: 2 wickets
# MP Stoinis: 3 wickets
# T Shamsi: 7 wickets
# DJ Mitchell: 0 wickets
# JE Root: 1 wickets
# CBRLS Kumara: 3 wickets
# C Karunaratne: 0 wickets
# Nasum Ahmed: 0 wickets
# Hasan Mahmud: 3 wickets
# Usama Mir: 4 wickets
# MADI Hemantha: 0 wickets
# DJ Willey: 8 wickets
# AAP Atkinson: 2 wickets
# Mohammed Shami: 16 wickets
# Noor Ahmad: 5 wickets
# LB Williams: 2 wickets
# AD Mathews: 6 wickets
# AK Markram: 0 wickets
# Mohammad Wasim: 8 wickets
# Shariz Ahmad: 0 wickets
# PVD Chameera: 2 wickets
# Nazmul Hossain Shanto: 0 wickets
# TG Southee: 4 wickets
# Agha Salman: 0 wickets
# IS Sodhi: 0 wickets
# TM Head: 0 wickets
# Tanzim Hasan Sakib: 3 wickets
# AL Phehlukwayo: 1 wickets
# Rahmat Shah: 0 wickets
# JM Bairstow: 0 wickets
# DJ Malan: 0 wickets
# HC Brook: 0 wickets
# JC Buttler: 0 wickets
# DP Conway: 0 wickets
# WA Young: 0 wickets
# Fakhar Zaman: 0 wickets
# Imam-ul-Haq: 0 wickets
# Babar Azam: 0 wickets
# Mohammad Rizwan: 0 wickets
# Saud Shakeel: 0 wickets
# MP O'Dowd: 0 wickets
# AT Nidamanuru: 0 wickets
# SA Edwards: 0 wickets
# Rahmanullah Gurbaz: 0 wickets
# Ibrahim Zadran: 0 wickets
# Hashmatullah Shahidi: 0 wickets
# Najibullah Zadran: 0 wickets
# Tanzid Hasan: 0 wickets
# Liton Das: 0 wickets
# Mushfiqur Rahim: 0 wickets
# Q de Kock: 0 wickets
# T Bavuma: 0 wickets
# HE van der Dussen: 0 wickets
# H Klaasen: 0 wickets
# DA Miller: 0 wickets
# P Nissanka: 0 wickets
# MDKJ Perera: 0 wickets
# BKG Mendis: 0 wickets
# S Samarawickrama: 0 wickets
# DA Warner: 0 wickets
# SPD Smith: 0 wickets
# M Labuschagne: 0 wickets
# AT Carey: 0 wickets
# RG Sharma: 0 wickets
# Ishan Kishan: 0 wickets
# V Kohli: 0 wickets
# SS Iyer: 0 wickets
# KL Rahul: 0 wickets
# TWM Latham: 0 wickets
# MS Chapman: 0 wickets
# SA Engelbrecht: 0 wickets
# Towhid Hridoy: 0 wickets
# Abdullah Shafique: 0 wickets
# JP Inglis: 0 wickets
# KS Williamson: 0 wickets
# Shubman Gill: 0 wickets
# Ikram Alikhil: 0 wickets
# RR Hendricks: 0 wickets
# BA Stokes: 0 wickets
# SA Yadav: 0 wickets
# W Barresi: 0 wickets
# FDM Karunaratne: 0 wickets
# Bowler-wise wickets data has been saved to /content/bowler_wickets.csv

# %%
from google.colab import files

# Specify the path to your CSV file
csv_file_path = '/content/drive/MyDrive/bowler_wickets.csv'  # Update this path if necessary

# Trigger the download of the CSV file
files.download(csv_file_path)

# %%
import json
import os
import csv

# List of all player names
player_names =['TA Boult', 'MJ Henry', 'MJ Santner', 'JDS Neesham', 'R Ravindra',
       'GD Phillips', 'CR Woakes', 'SM Curran', 'MA Wood', 'MM Ali',
       'AU Rashid', 'LS Livingstone', 'A Dutt', 'LV van Beek',
       'CN Ackermann', 'PA van Meekeren', 'BFW de Leede',
       'RE van der Merwe', 'Vikramjit Singh', 'Saqib Zulfiqar',
       'Shaheen Shah Afridi', 'Hasan Ali', 'Haris Rauf', 'Iftikhar Ahmed',
       'Mohammad Nawaz', 'Shadab Khan', 'Taskin Ahmed', 'Shoriful Islam',
       'Mustafizur Rahman', 'Shakib Al Hasan', 'Mehedi Hasan Miraz',
       'Mahmudullah', 'Fazalhaq Farooqi', 'Mujeeb Ur Rahman',
       'Naveen-ul-Haq', 'Rashid Khan', 'Mohammad Nabi',
       'Azmatullah Omarzai', 'CAK Rajitha', 'D Madushanka', 'MD Shanaka',
       'DM de Silva', 'M Pathirana', 'DN Wellalage', 'L Ngidi',
       'M Jansen', 'K Rabada', 'KA Maharaj', 'G Coetzee', 'JJ Bumrah',
       'Mohammed Siraj', 'HH Pandya', 'R Ashwin', 'Kuldeep Yadav',
       'RA Jadeja', 'MA Starc', 'JR Hazlewood', 'PJ Cummins',
       'GJ Maxwell', 'C Green', 'A Zampa', 'R Klein', 'LH Ferguson',
       'Mahedi Hasan', 'RJW Topley', 'M Theekshana', 'KIC Asalanka',
       'SN Thakur', 'MR Marsh', 'MP Stoinis', 'T Shamsi', 'DJ Mitchell',
       'JE Root', 'CBRLS Kumara', 'C Karunaratne', 'Nasum Ahmed',
       'Hasan Mahmud', 'Usama Mir', 'MADI Hemantha', 'DJ Willey',
       'AAP Atkinson', 'Mohammed Shami', 'Noor Ahmad', 'LB Williams',
       'AD Mathews', 'AK Markram', 'Mohammad Wasim', 'Shariz Ahmad',
       'PVD Chameera', 'Nazmul Hossain Shanto', 'TG Southee',
       'Agha Salman', 'IS Sodhi', 'TM Head', 'Tanzim Hasan Sakib',
       'AL Phehlukwayo', 'Rahmat Shah', 'JM Bairstow', 'DJ Malan',
       'HC Brook', 'JC Buttler', 'DP Conway', 'WA Young', 'Fakhar Zaman',
       'Imam-ul-Haq', 'Babar Azam', 'Mohammad Rizwan', 'Saud Shakeel',
       "MP O'Dowd", 'AT Nidamanuru', 'SA Edwards', 'Rahmanullah Gurbaz',
       'Ibrahim Zadran', 'Hashmatullah Shahidi', 'Najibullah Zadran',
       'Tanzid Hasan', 'Liton Das', 'Mushfiqur Rahim', 'Q de Kock',
       'T Bavuma', 'HE van der Dussen', 'H Klaasen', 'DA Miller',
       'P Nissanka', 'MDKJ Perera', 'BKG Mendis', 'S Samarawickrama',
       'DA Warner', 'SPD Smith', 'M Labuschagne', 'AT Carey', 'RG Sharma',
       'Ishan Kishan', 'V Kohli', 'SS Iyer', 'KL Rahul', 'TWM Latham',
       'MS Chapman', 'SA Engelbrecht', 'Towhid Hridoy',
       'Abdullah Shafique', 'JP Inglis', 'KS Williamson', 'Shubman Gill',
       'Ikram Alikhil', 'RR Hendricks', 'BA Stokes', 'SA Yadav',
       'W Barresi', 'FDM Karunaratne']


# Dictionary to store the number of matches played by each player
matches_played_by_player = {player: 0 for player in player_names}

# Directory containing the JSON files
json_folder_path = '/content/data/odis_json'  # Replace with the actual folder path containing JSON files

# Iterate through JSON files in the folder
for filename in os.listdir(json_folder_path):
    if filename.endswith('.json'):  # Check if the file has a .json extension
        with open(os.path.join(json_folder_path, filename), 'r') as jsonfile:
            data = json.load(jsonfile)

            # Check if the gender is male
            if data['info']['gender'] == 'male':
                # Set to keep track of players found in this file
                players_found_in_file = set()

                for inning in data['innings']:
                    for over in inning['overs']:
                        for ball in over['deliveries']:
                            batter = ball['batter']
                            bowler = ball['bowler']

                            # Check if names exist in the list of player names
                            if batter in player_names:
                                players_found_in_file.add(batter)
                            if bowler in player_names:
                                players_found_in_file.add(bowler)

                # Increment the match count for players found in this file
                for player in players_found_in_file:
                    matches_played_by_player[player] += 1

# Print the total number of matches played by each player
for player, matches_played in matches_played_by_player.items():
    print(f"{player}: {matches_played} matches")

# Write the data to a CSV file
csv_file_path = '/content/player_matches_played.csv'  # Replace with the desired CSV file path
with open(csv_file_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)

    # Write header row
    csvwriter.writerow(['Player Name', 'Matches Played'])

    # Write player statistics rows
    for player, matches_played in matches_played_by_player.items():
        csvwriter.writerow([player, matches_played])

print(f"Player matches played data has been saved to {csv_file_path}")
# Out:
# TA Boult: 9 matches
# MJ Henry: 7 matches
# MJ Santner: 9 matches
# JDS Neesham: 3 matches
# R Ravindra: 9 matches
# GD Phillips: 9 matches
# CR Woakes: 7 matches
# SM Curran: 3 matches
# MA Wood: 7 matches
# MM Ali: 5 matches
# AU Rashid: 8 matches
# LS Livingstone: 6 matches
# A Dutt: 8 matches
# LV van Beek: 7 matches
# CN Ackermann: 8 matches
# PA van Meekeren: 8 matches
# BFW de Leede: 8 matches
# RE van der Merwe: 7 matches
# Vikramjit Singh: 6 matches
# Saqib Zulfiqar: 2 matches
# Shaheen Shah Afridi: 8 matches
# Hasan Ali: 6 matches
# Haris Rauf: 8 matches
# Iftikhar Ahmed: 8 matches
# Mohammad Nawaz: 5 matches
# Shadab Khan: 5 matches
# Taskin Ahmed: 6 matches
# Shoriful Islam: 8 matches
# Mustafizur Rahman: 7 matches
# Shakib Al Hasan: 7 matches
# Mehedi Hasan Miraz: 8 matches
# Mahmudullah: 7 matches
# Fazalhaq Farooqi: 6 matches
# Mujeeb Ur Rahman: 9 matches
# Naveen-ul-Haq: 8 matches
# Rashid Khan: 9 matches
# Mohammad Nabi: 9 matches
# Azmatullah Omarzai: 9 matches
# CAK Rajitha: 6 matches
# D Madushanka: 9 matches
# MD Shanaka: 2 matches
# DM de Silva: 8 matches
# M Pathirana: 2 matches
# DN Wellalage: 3 matches
# L Ngidi: 8 matches
# M Jansen: 8 matches
# K Rabada: 8 matches
# KA Maharaj: 9 matches
# G Coetzee: 7 matches
# JJ Bumrah: 8 matches
# Mohammed Siraj: 8 matches
# HH Pandya: 4 matches
# R Ashwin: 1 matches
# Kuldeep Yadav: 8 matches
# RA Jadeja: 8 matches
# MA Starc: 8 matches
# JR Hazlewood: 8 matches
# PJ Cummins: 8 matches
# GJ Maxwell: 7 matches
# C Green: 3 matches
# A Zampa: 8 matches
# R Klein: 1 matches
# LH Ferguson: 6 matches
# Mahedi Hasan: 2 matches
# RJW Topley: 3 matches
# M Theekshana: 8 matches
# KIC Asalanka: 8 matches
# SN Thakur: 3 matches
# MR Marsh: 7 matches
# MP Stoinis: 5 matches
# T Shamsi: 3 matches
# DJ Mitchell: 8 matches
# JE Root: 8 matches
# CBRLS Kumara: 2 matches
# C Karunaratne: 3 matches
# Nasum Ahmed: 2 matches
# Hasan Mahmud: 2 matches
# Usama Mir: 4 matches
# MADI Hemantha: 2 matches
# DJ Willey: 5 matches
# AAP Atkinson: 2 matches
# Mohammed Shami: 4 matches
# Noor Ahmad: 4 matches
# LB Williams: 1 matches
# AD Mathews: 5 matches
# AK Markram: 9 matches
# Mohammad Wasim: 3 matches
# Shariz Ahmad: 1 matches
# PVD Chameera: 4 matches
# Nazmul Hossain Shanto: 8 matches
# TG Southee: 3 matches
# Agha Salman: 1 matches
# IS Sodhi: 1 matches
# TM Head: 3 matches
# Tanzim Hasan Sakib: 1 matches
# AL Phehlukwayo: 1 matches
# Rahmat Shah: 9 matches
# JM Bairstow: 8 matches
# DJ Malan: 8 matches
# HC Brook: 5 matches
# JC Buttler: 8 matches
# DP Conway: 9 matches
# WA Young: 6 matches
# Fakhar Zaman: 3 matches
# Imam-ul-Haq: 6 matches
# Babar Azam: 8 matches
# Mohammad Rizwan: 7 matches
# Saud Shakeel: 6 matches
# MP O'Dowd: 8 matches
# AT Nidamanuru: 6 matches
# SA Edwards: 8 matches
# Rahmanullah Gurbaz: 9 matches
# Ibrahim Zadran: 9 matches
# Hashmatullah Shahidi: 9 matches
# Najibullah Zadran: 2 matches
# Tanzid Hasan: 8 matches
# Liton Das: 8 matches
# Mushfiqur Rahim: 8 matches
# Q de Kock: 9 matches
# T Bavuma: 7 matches
# HE van der Dussen: 9 matches
# H Klaasen: 9 matches
# DA Miller: 9 matches
# P Nissanka: 9 matches
# MDKJ Perera: 7 matches
# BKG Mendis: 9 matches
# S Samarawickrama: 9 matches
# DA Warner: 8 matches
# SPD Smith: 7 matches
# M Labuschagne: 8 matches
# AT Carey: 1 matches
# RG Sharma: 8 matches
# Ishan Kishan: 2 matches
# V Kohli: 8 matches
# SS Iyer: 8 matches
# KL Rahul: 7 matches
# TWM Latham: 7 matches
# MS Chapman: 5 matches
# SA Engelbrecht: 7 matches
# Towhid Hridoy: 5 matches
# Abdullah Shafique: 7 matches
# JP Inglis: 7 matches
# KS Williamson: 3 matches
# Shubman Gill: 6 matches
# Ikram Alikhil: 3 matches
# RR Hendricks: 2 matches
# BA Stokes: 5 matches
# SA Yadav: 4 matches
# W Barresi: 3 matches
# FDM Karunaratne: 2 matches
# Player matches played data has been saved to /content/player_matches_played.csv

# %%
from google.colab import files

# Specify the path to your CSV file
csv_file_path = '/content/player_matches_played.csv'  # Update this path if necessary

# Trigger the download of the CSV file
files.download(csv_file_path)

# %%
import os
import json

# List of players
players_list = ['TA Boult', 'MJ Henry', 'MJ Santner', 'JDS Neesham', 'R Ravindra',
       'GD Phillips', 'CR Woakes', 'SM Curran', 'MA Wood', 'MM Ali',
       'AU Rashid', 'LS Livingstone', 'A Dutt', 'LV van Beek',
       'CN Ackermann', 'PA van Meekeren', 'BFW de Leede',
       'RE van der Merwe', 'Vikramjit Singh', 'Saqib Zulfiqar',
       'Shaheen Shah Afridi', 'Hasan Ali', 'Haris Rauf', 'Iftikhar Ahmed',
       'Mohammad Nawaz', 'Shadab Khan', 'Taskin Ahmed', 'Shoriful Islam',
       'Mustafizur Rahman', 'Shakib Al Hasan', 'Mehedi Hasan Miraz',
       'Mahmudullah', 'Fazalhaq Farooqi', 'Mujeeb Ur Rahman',
       'Naveen-ul-Haq', 'Rashid Khan', 'Mohammad Nabi',
       'Azmatullah Omarzai', 'CAK Rajitha', 'D Madushanka', 'MD Shanaka',
       'DM de Silva', 'M Pathirana', 'DN Wellalage', 'L Ngidi',
       'M Jansen', 'K Rabada', 'KA Maharaj', 'G Coetzee', 'JJ Bumrah',
       'Mohammed Siraj', 'HH Pandya', 'R Ashwin', 'Kuldeep Yadav',
       'RA Jadeja', 'MA Starc', 'JR Hazlewood', 'PJ Cummins',
       'GJ Maxwell', 'C Green', 'A Zampa', 'R Klein', 'LH Ferguson',
       'Mahedi Hasan', 'RJW Topley', 'M Theekshana', 'KIC Asalanka',
       'SN Thakur', 'MR Marsh', 'MP Stoinis', 'T Shamsi', 'DJ Mitchell',
       'JE Root', 'CBRLS Kumara', 'C Karunaratne', 'Nasum Ahmed',
       'Hasan Mahmud', 'Usama Mir', 'MADI Hemantha', 'DJ Willey',
       'AAP Atkinson', 'Mohammed Shami', 'Noor Ahmad', 'LB Williams',
       'AD Mathews', 'AK Markram', 'Mohammad Wasim', 'Shariz Ahmad',
       'PVD Chameera', 'Nazmul Hossain Shanto', 'TG Southee',
       'Agha Salman', 'IS Sodhi', 'TM Head', 'Tanzim Hasan Sakib',
       'AL Phehlukwayo', 'Rahmat Shah', 'JM Bairstow', 'DJ Malan',
       'HC Brook', 'JC Buttler', 'DP Conway', 'WA Young', 'Fakhar Zaman',
       'Imam-ul-Haq', 'Babar Azam', 'Mohammad Rizwan', 'Saud Shakeel',
       "MP O'Dowd", 'AT Nidamanuru', 'SA Edwards', 'Rahmanullah Gurbaz',
       'Ibrahim Zadran', 'Hashmatullah Shahidi', 'Najibullah Zadran',
       'Tanzid Hasan', 'Liton Das', 'Mushfiqur Rahim', 'Q de Kock',
       'T Bavuma', 'HE van der Dussen', 'H Klaasen', 'DA Miller',
       'P Nissanka', 'MDKJ Perera', 'BKG Mendis', 'S Samarawickrama',
       'DA Warner', 'SPD Smith', 'M Labuschagne', 'AT Carey', 'RG Sharma',
       'Ishan Kishan', 'V Kohli', 'SS Iyer', 'KL Rahul', 'TWM Latham',
       'MS Chapman', 'SA Engelbrecht', 'Towhid Hridoy',
       'Abdullah Shafique', 'JP Inglis', 'KS Williamson', 'Shubman Gill',
       'Ikram Alikhil', 'RR Hendricks', 'BA Stokes', 'SA Yadav',
       'W Barresi', 'FDM Karunaratne']


# Folder containing multiple JSON files
folder_path = '/content/data/odis_json'

# Dictionary to store balls faced by each player
balls_faced_by_player = {player: 0 for player in players_list}

# Function to count balls faced by a batsman in an inning
def count_balls_faced(inning, batsman):
    balls_faced = 0
    for over in inning['overs']:
        for delivery in over['deliveries']:
            if delivery['batter'] == batsman:
                balls_faced += 1
    return balls_faced

# Iterate through all JSON files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)

        # Load JSON data from file
        with open(file_path, 'r') as json_file:
            data = json.load(json_file)

        # Iterate through innings
        for inning in data['innings']:
            # Iterate through batsmen in each inning
            for batsman in players_list:
                balls_faced_by_player[batsman] += count_balls_faced(inning, batsman)

# Print total balls faced by each player
for player, balls_faced in balls_faced_by_player.items():
    print(f"{player} faced {balls_faced} balls across all matches.")
# Out:
# TA Boult faced 23 balls across all matches.
# MJ Henry faced 22 balls across all matches.
# MJ Santner faced 71 balls across all matches.
# JDS Neesham faced 50 balls across all matches.
# R Ravindra faced 537 balls across all matches.
# GD Phillips faced 228 balls across all matches.
# CR Woakes faced 157 balls across all matches.
# SM Curran faced 57 balls across all matches.
# MA Wood faced 66 balls across all matches.
# MM Ali faced 125 balls across all matches.
# AU Rashid faced 94 balls across all matches.
# LS Livingstone faced 94 balls across all matches.
# A Dutt faced 80 balls across all matches.
# LV van Beek faced 174 balls across all matches.
# CN Ackermann faced 239 balls across all matches.
# PA van Meekeren faced 52 balls across all matches.
# BFW de Leede faced 182 balls across all matches.
# RE van der Merwe faced 83 balls across all matches.
# Vikramjit Singh faced 153 balls across all matches.
# Saqib Zulfiqar faced 33 balls across all matches.
# Shaheen Shah Afridi faced 38 balls across all matches.
# Hasan Ali faced 29 balls across all matches.
# Haris Rauf faced 22 balls across all matches.
# Iftikhar Ahmed faced 124 balls across all matches.
# Mohammad Nawaz faced 100 balls across all matches.
# Shadab Khan faced 117 balls across all matches.
# Taskin Ahmed faced 93 balls across all matches.
# Shoriful Islam faced 29 balls across all matches.
# Mustafizur Rahman faced 92 balls across all matches.
# Shakib Al Hasan faced 229 balls across all matches.
# Mehedi Hasan Miraz faced 238 balls across all matches.
# Mahmudullah faced 341 balls across all matches.
# Fazalhaq Farooqi faced 9 balls across all matches.
# Mujeeb Ur Rahman faced 40 balls across all matches.
# Naveen-ul-Haq faced 25 balls across all matches.
# Rashid Khan faced 115 balls across all matches.
# Mohammad Nabi faced 77 balls across all matches.
# Azmatullah Omarzai faced 370 balls across all matches.
# CAK Rajitha faced 60 balls across all matches.
# D Madushanka faced 69 balls across all matches.
# MD Shanaka faced 83 balls across all matches.
# DM de Silva faced 186 balls across all matches.
# M Pathirana faced 19 balls across all matches.
# DN Wellalage faced 18 balls across all matches.
# L Ngidi faced 43 balls across all matches.
# M Jansen faced 146 balls across all matches.
# K Rabada faced 33 balls across all matches.
# KA Maharaj faced 76 balls across all matches.
# G Coetzee faced 39 balls across all matches.
# JJ Bumrah faced 26 balls across all matches.
# Mohammed Siraj faced 0 balls across all matches.
# HH Pandya faced 8 balls across all matches.
# R Ashwin faced 0 balls across all matches.
# Kuldeep Yadav faced 15 balls across all matches.
# RA Jadeja faced 99 balls across all matches.
# MA Starc faced 120 balls across all matches.
# JR Hazlewood faced 5 balls across all matches.
# PJ Cummins faced 165 balls across all matches.
# GJ Maxwell faced 265 balls across all matches.
# C Green faced 86 balls across all matches.
# A Zampa faced 63 balls across all matches.
# R Klein faced 15 balls across all matches.
# LH Ferguson faced 6 balls across all matches.
# Mahedi Hasan faced 72 balls across all matches.
# RJW Topley faced 9 balls across all matches.
# M Theekshana faced 189 balls across all matches.
# KIC Asalanka faced 345 balls across all matches.
# SN Thakur faced 0 balls across all matches.
# MR Marsh faced 262 balls across all matches.
# MP Stoinis faced 80 balls across all matches.
# T Shamsi faced 11 balls across all matches.
# DJ Mitchell faced 390 balls across all matches.
# JE Root faced 244 balls across all matches.
# CBRLS Kumara faced 8 balls across all matches.
# C Karunaratne faced 28 balls across all matches.
# Nasum Ahmed faced 37 balls across all matches.
# Hasan Mahmud faced 25 balls across all matches.
# Usama Mir faced 3 balls across all matches.
# MADI Hemantha faced 4 balls across all matches.
# DJ Willey faced 64 balls across all matches.
# AAP Atkinson faced 25 balls across all matches.
# Mohammed Shami faced 10 balls across all matches.
# Noor Ahmad faced 32 balls across all matches.
# LB Williams faced 0 balls across all matches.
# AD Mathews faced 80 balls across all matches.
# AK Markram faced 357 balls across all matches.
# Mohammad Wasim faced 11 balls across all matches.
# Shariz Ahmad faced 8 balls across all matches.
# PVD Chameera faced 39 balls across all matches.
# Nazmul Hossain Shanto faced 236 balls across all matches.
# TG Southee faced 11 balls across all matches.
# Agha Salman faced 0 balls across all matches.
# IS Sodhi faced 0 balls across all matches.
# TM Head faced 80 balls across all matches.
# Tanzim Hasan Sakib faced 6 balls across all matches.
# AL Phehlukwayo faced 40 balls across all matches.
# Rahmat Shah faced 429 balls across all matches.
# JM Bairstow faced 184 balls across all matches.
# DJ Malan faced 377 balls across all matches.
# HC Brook faced 134 balls across all matches.
# JC Buttler faced 126 balls across all matches.
# DP Conway faced 362 balls across all matches.
# WA Young faced 248 balls across all matches.
# Fakhar Zaman faced 173 balls across all matches.
# Imam-ul-Haq faced 181 balls across all matches.
# Babar Azam faced 347 balls across all matches.
# Mohammad Rizwan faced 368 balls across all matches.
# Saud Shakeel faced 223 balls across all matches.
# MP O'Dowd faced 168 balls across all matches.
# AT Nidamanuru faced 132 balls across all matches.
# SA Edwards faced 272 balls across all matches.
# Rahmanullah Gurbaz faced 290 balls across all matches.
# Ibrahim Zadran faced 510 balls across all matches.
# Hashmatullah Shahidi faced 438 balls across all matches.
# Najibullah Zadran faced 21 balls across all matches.
# Tanzid Hasan faced 124 balls across all matches.
# Liton Das faced 315 balls across all matches.
# Mushfiqur Rahim faced 235 balls across all matches.
# Q de Kock faced 555 balls across all matches.
# T Bavuma faced 196 balls across all matches.
# HE van der Dussen faced 507 balls across all matches.
# H Klaasen faced 239 balls across all matches.
# DA Miller faced 223 balls across all matches.
# P Nissanka faced 380 balls across all matches.
# MDKJ Perera faced 153 balls across all matches.
# BKG Mendis faced 269 balls across all matches.
# S Samarawickrama faced 370 balls across all matches.
# DA Warner faced 423 balls across all matches.
# SPD Smith faced 241 balls across all matches.
# M Labuschagne faced 375 balls across all matches.
# AT Carey faced 2 balls across all matches.
# RG Sharma faced 365 balls across all matches.
# Ishan Kishan faced 49 balls across all matches.
# V Kohli faced 633 balls across all matches.
# SS Iyer faced 308 balls across all matches.
# KL Rahul faced 310 balls across all matches.
# TWM Latham faced 171 balls across all matches.
# MS Chapman faced 68 balls across all matches.
# SA Engelbrecht faced 386 balls across all matches.
# Towhid Hridoy faced 134 balls across all matches.
# Abdullah Shafique faced 370 balls across all matches.
# JP Inglis faced 122 balls across all matches.
# KS Williamson faced 204 balls across all matches.
# Shubman Gill faced 233 balls across all matches.
# Ikram Alikhil faced 103 balls across all matches.
# RR Hendricks faced 94 balls across all matches.
# BA Stokes faced 271 balls across all matches.
# SA Yadav faced 75 balls across all matches.
# W Barresi faced 112 balls across all matches.
# FDM Karunaratne faced 22 balls across all matches.

# %%
import os
import json
import csv
from google.colab import files

csv_file_path = 'balls_faced_by_player.csv'
with open(csv_file_path, 'w', newline='') as csvfile:
    fieldnames = ['Player', 'Balls Faced']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for player, balls_faced in balls_faced_by_player.items():
        writer.writerow({'Player': player, 'Balls Faced': balls_faced})

# Download the CSV file
files.download(csv_file_path)
